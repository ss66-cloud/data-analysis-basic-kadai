# %% [markdown]
# <a href="https://colab.research.google.com/github/ss66-cloud/data-analysis-basic-kadai/blob/main/kadai_005/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# oresen
fig, axes = plt.subplots(2, 3, tight_layout = True)
y0 = [1,2,-5,2]
axes[0,0].plot(y0)

# sin function
x = np.linspace(0, 10, 30)
y = 2 + 2 * np.sin(2 * x)
axes[0,1].plot(x,y)

#histogram  mada
x = np.random.normal(15,5,2000)
axes[0,2].hist(x)

#sanpuzu
np.random.seed(3)
x = 4 + np.random.normal(0,2,60)
y = 4 + np.random.normal(0,2,len(x))
axes[1,0].scatter(x,y)

plt.show()
